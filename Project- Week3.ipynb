# %% [markdown]
# # Capstone Project
# ### this notebook will be mainly used for the capstone project.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
wiki_link="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page=requests.get(wiki_link).text
soup = BeautifulSoup(page,'xml')
#soup

# %% [markdown]
# # Extract data from table

# %%
tables = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# %% [markdown]
# ## Reading table data

# %%
for table in tables.find_all('tr'):
    count=1
    Borough_var=-1
    postcode_var=-1
    Neighbor_var=-1
    t= table.find_all('td')
    for i in t:
        if count==1:
            postcode_var=i.text
        if count==2:
            Borough_var=i.text
            tag_borough=i.find('a')
        if count==3:
            Neighbor_var=str(i.text).strip()
            tag_neighbor=i.find('a')
        
        count+=1
        #print(t)
    if (Borough_var == 'Not assigned'):
        continue
    if (Neighbor_var=='Not assigned') and (Borough_var != 'Not assigned'):
        Neighbor_var=Borough_var
    try:
        if (tag_borough is None):
            continue
    except:
        pass

    
    Postcode.append(postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbor_var)

# %%
l=len(Postcode)
m=set(Postcode)
print(len(m))
# Out:
# 100

# %% [markdown]
# ## Converting to table dataframe

# %%
Post_u      = []
Bor_u       = []
Neighbour_u = []


for post in m:
    p_var = ''; b_var = ''; n_var = ''; 
    for post_id, n in enumerate(Postcode):
        if post == n:
            p_var = post;
            b_var = Borough[post_id]
            if n_var == '': 
                n_var = Neighbourhood[post_id]
            else:
                n_var = n_var + ', ' + Neighbourhood[post_id]
    Post_u.append(p_var)
    Bor_u.append(b_var)
    Neighbour_u.append(n_var)

# %%
toronto={'Postcode':Post_u,'Borough': Bor_u,'Neighbourhood':Neighbour_u}
df=pd.DataFrame.from_dict(toronto)
df.head(30)
# Out:
#    Postcode           Borough  \
# 0       M5X  Downtown Toronto
# 1       M9B         Etobicoke
# 2       M2J        North York
# 3       M3K        North York
# 4       M4K      East Toronto
# 5       M5C  Downtown Toronto
# 6       M5W  Downtown Toronto
# 7       M9A         Etobicoke
# 8       M6J      West Toronto
# 9       M9R         Etobicoke
# 10      M1M       Scarborough
# 11      M9V         Etobicoke
# 12      M2M        North York
# 13      M1L       Scarborough
# 14      M3H        North York
# 15      M5P   Central Toronto
# 16      M2N        North York
# 17      M5N   Central Toronto
# 18      M5B  Downtown Toronto
# 19      M7Y      East Toronto
# 20      M5H  Downtown Toronto
# 21      M1B       Scarborough
# 22      M8Z         Etobicoke
# 23      M4N   Central Toronto
# 24      M6K      West Toronto
# 25      M4G         East York
# 26      M9P         Etobicoke
# 27      M2H        North York
# 28      M1H       Scarborough
# 29      M8X         Etobicoke
#
#                                         Neighbourhood
# 0              First Canadian Place, Underground city
# 1   Cloverdale, Islington, Martin Grove, Princess ...
# 2                        Fairview, Henry Farm, Oriole
# 3                         CFB Toronto, Downsview East
# 4                        The Danforth West, Riverdale
# 5                                      St. James Town
# 6                     Stn A PO Boxes 25 The Esplanade
# 7                                    Islington Avenue
# 8                            Little Portugal, Trinity
# 9   Kingsview Village, Martin Grove Gardens, Richv...
# 10    Cliffcrest, Cliffside, Scarborough Village West
# 11  Albion Gardens, Beaumond Heights, Humbergate, ...
# 12                            Newtonbrook, Willowdale
# 13                    Clairlea, Golden Mile, Oakridge
# 14    Bathurst Manor, Downsview North, Wilson Heights
# 15                Forest Hill North, Forest Hill West
# 16                                   Willowdale South
# 17                                           Roselawn
# 18                           Ryerson, Garden District
# 19  Business Reply Mail Processing Centre 969 Eastern
# 20                           Adelaide, King, Richmond
# 21                                     Rouge, Malvern
# 22  Kingsway Park South West, Mimico NW, The Queen...
# 23                                      Lawrence Park
# 24       Brockton, Exhibition Place, Parkdale Village
# 25                                            Leaside
# 26                                          Westmount
# 27                                  Hillcrest Village
# 28                                          Cedarbrae
# 29      The Kingsway, Montgomery Road, Old Mill North

# %%
df.shape
# Out:
# (100, 3)
